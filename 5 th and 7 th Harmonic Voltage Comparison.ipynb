# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# Raw data from the results
data_5th = """
Puttalam Junction             : Voltage Magnitude = 0.7857 pu
New Anuradhapura Junction     : Voltage Magnitude = 1.5091 pu
Vavuniya Junction             : Voltage Magnitude = 1.9958 pu
Mannar Junction               : Voltage Magnitude = 2.3502 pu
Nadukuda Junction             : Voltage Magnitude = 2.3832 pu
New Chilaw Junction           : Voltage Magnitude = 0.3511 pu
Veyangoda Junction            : Voltage Magnitude = 0.7423 pu
Kotugoda Junction             : Voltage Magnitude = 0.8929 pu
New Kerawalapitiya Junction   : Voltage Magnitude = 0.8974 pu
New Kerawalapitiya 2 Junction : Voltage Magnitude = 0.9612 pu
Kerawalapitiya Junction       : Voltage Magnitude = 0.9623 pu
Colombo-L Junction            : Voltage Magnitude = 0.9898 pu
Biyagama Junction             : Voltage Magnitude = 0.9573 pu
Kelaniya Junction             : Voltage Magnitude = 0.9351 pu
Barge Junction                : Voltage Magnitude = 0.9312 pu
Pannipitiya Junction          : Voltage Magnitude = 0.9744 pu
Panni D2 Junction             : Voltage Magnitude = 1.0161 pu
Padukka Junction              : Voltage Magnitude = 1.0471 pu
New Polpitiya Junction        : Voltage Magnitude = 1.0714 pu
Hambantota Junction           : Voltage Magnitude = 1.5927 pu
Kotmale Junction              : Voltage Magnitude = 0.9108 pu
Upper Kotmale Junction        : Voltage Magnitude = 0.9153 pu
Victoria Junction             : Voltage Magnitude = 0.8606 pu
Randenigala Junction          : Voltage Magnitude = 0.7689 pu
Rantambe Junction             : Voltage Magnitude = 0.7558 pu
New Habarana Junction         : Voltage Magnitude = 0.4548 pu
"""

data_7th = """
Puttalam Junction             : Voltage Magnitude = 0.3975 pu
New Anuradhapura Junction     : Voltage Magnitude = 0.0494 pu
Vavuniya Junction             : Voltage Magnitude = 0.2017 pu
Mannar Junction               : Voltage Magnitude = 0.4559 pu
Nadukuda Junction             : Voltage Magnitude = 0.4813 pu
New Chilaw Junction           : Voltage Magnitude = 0.1380 pu
Veyangoda Junction            : Voltage Magnitude = 0.1058 pu
Kotugoda Junction             : Voltage Magnitude = 0.1788 pu
New Kerawalapitiya Junction   : Voltage Magnitude = 0.1823 pu
New Kerawalapitiya 2 Junction : Voltage Magnitude = 0.2709 pu
Kerawalapitiya Junction       : Voltage Magnitude = 0.2725 pu
Colombo-L Junction            : Voltage Magnitude = 0.3187 pu
Biyagama Junction             : Voltage Magnitude = 0.1352 pu
Kelaniya Junction             : Voltage Magnitude = 0.1385 pu
Barge Junction                : Voltage Magnitude = 0.1401 pu
Pannipitiya Junction          : Voltage Magnitude = 0.1419 pu
Panni D2 Junction             : Voltage Magnitude = 0.1074 pu
Padukka Junction              : Voltage Magnitude = 0.0877 pu
New Polpitiya Junction        : Voltage Magnitude = 0.0345 pu
Hambantota Junction           : Voltage Magnitude = 0.5378 pu
Kotmale Junction              : Voltage Magnitude = 0.1509 pu
Upper Kotmale Junction        : Voltage Magnitude = 0.1538 pu
Victoria Junction             : Voltage Magnitude = 0.2987 pu
Randenigala Junction          : Voltage Magnitude = 0.4425 pu
Rantambe Junction             : Voltage Magnitude = 0.4684 pu
New Habarana Junction         : Voltage Magnitude = 0.1466 pu
"""

# Function to extract junction names and voltage values
def parse_data(text):
    names = []
    values = []
    for line in text.strip().split('\n'):
        if ':' in line:
            name, rest = line.split(':', 1)
            val = re.search(r'[\d\.]+', rest)
            if val:
                # Clean up the junction name for cleaner plotting
                names.append(name.strip().replace(' Junction', ''))
                values.append(float(val.group()))
    return names, values

# Parse the data
names_5th, vals_5th = parse_data(data_5th)
names_7th, vals_7th = parse_data(data_7th)

# Create the plot
fig, ax = plt.subplots(figsize=(16, 8))

# Plotting the lines
ax.plot(names_5th, vals_5th, marker='o', linestyle='-', linewidth=2, label='5th Harmonic', color='#1f77b4')
ax.plot(names_7th, vals_7th, marker='s', linestyle='-', linewidth=2, label='7th Harmonic', color='#ff7f0e')

# Add labels, title, and formatting
ax.set_ylabel('Voltage Magnitude (pu)', fontsize=12)
ax.set_title('Line Chart Comparison of 5th and 7th Harmonic Voltages', fontsize=14)
ax.set_xticks(range(len(names_5th)))
ax.set_xticklabels(names_5th, rotation=45, ha='right', fontsize=10)
ax.legend(fontsize=12)
ax.grid(True, linestyle='--', alpha=0.7)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Use plt.savefig('harmonic_voltage_line_chart.png', dpi=300) to save the image

# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# Raw data from the results
data_5th = """
Puttalam Junction             : Voltage Magnitude = 0.7857 pu
New Anuradhapura Junction     : Voltage Magnitude = 1.5091 pu
Vavuniya Junction             : Voltage Magnitude = 1.9958 pu
Mannar Junction               : Voltage Magnitude = 2.3502 pu
Nadukuda Junction             : Voltage Magnitude = 2.3832 pu
New Chilaw Junction           : Voltage Magnitude = 0.3511 pu
Veyangoda Junction            : Voltage Magnitude = 0.7423 pu
Kotugoda Junction             : Voltage Magnitude = 0.8929 pu
New Kerawalapitiya Junction   : Voltage Magnitude = 0.8974 pu
New Kerawalapitiya 2 Junction : Voltage Magnitude = 0.9612 pu
Kerawalapitiya Junction       : Voltage Magnitude = 0.9623 pu
Colombo-L Junction            : Voltage Magnitude = 0.9898 pu
Biyagama Junction             : Voltage Magnitude = 0.9573 pu
Kelaniya Junction             : Voltage Magnitude = 0.9351 pu
Barge Junction                : Voltage Magnitude = 0.9312 pu
Pannipitiya Junction          : Voltage Magnitude = 0.9744 pu
Panni D2 Junction             : Voltage Magnitude = 1.0161 pu
Padukka Junction              : Voltage Magnitude = 1.0471 pu
New Polpitiya Junction        : Voltage Magnitude = 1.0714 pu
Hambantota Junction           : Voltage Magnitude = 1.5927 pu
Kotmale Junction              : Voltage Magnitude = 0.9108 pu
Upper Kotmale Junction        : Voltage Magnitude = 0.9153 pu
Victoria Junction             : Voltage Magnitude = 0.8606 pu
Randenigala Junction          : Voltage Magnitude = 0.7689 pu
Rantambe Junction             : Voltage Magnitude = 0.7558 pu
New Habarana Junction         : Voltage Magnitude = 0.4548 pu
"""

data_7th = """
Puttalam Junction             : Voltage Magnitude = 0.3975 pu
New Anuradhapura Junction     : Voltage Magnitude = 0.0494 pu
Vavuniya Junction             : Voltage Magnitude = 0.2017 pu
Mannar Junction               : Voltage Magnitude = 0.4559 pu
Nadukuda Junction             : Voltage Magnitude = 0.4813 pu
New Chilaw Junction           : Voltage Magnitude = 0.1380 pu
Veyangoda Junction            : Voltage Magnitude = 0.1058 pu
Kotugoda Junction             : Voltage Magnitude = 0.1788 pu
New Kerawalapitiya Junction   : Voltage Magnitude = 0.1823 pu
New Kerawalapitiya 2 Junction : Voltage Magnitude = 0.2709 pu
Kerawalapitiya Junction       : Voltage Magnitude = 0.2725 pu
Colombo-L Junction            : Voltage Magnitude = 0.3187 pu
Biyagama Junction             : Voltage Magnitude = 0.1352 pu
Kelaniya Junction             : Voltage Magnitude = 0.1385 pu
Barge Junction                : Voltage Magnitude = 0.1401 pu
Pannipitiya Junction          : Voltage Magnitude = 0.1419 pu
Panni D2 Junction             : Voltage Magnitude = 0.1074 pu
Padukka Junction              : Voltage Magnitude = 0.0877 pu
New Polpitiya Junction        : Voltage Magnitude = 0.0345 pu
Hambantota Junction           : Voltage Magnitude = 0.5378 pu
Kotmale Junction              : Voltage Magnitude = 0.1509 pu
Upper Kotmale Junction        : Voltage Magnitude = 0.1538 pu
Victoria Junction             : Voltage Magnitude = 0.2987 pu
Randenigala Junction          : Voltage Magnitude = 0.4425 pu
Rantambe Junction             : Voltage Magnitude = 0.4684 pu
New Habarana Junction         : Voltage Magnitude = 0.1466 pu
"""

# Function to extract junction names and voltage values
def parse_data(text):
    names, values = [], []
    for line in text.strip().split('\n'):
        if ':' in line:
            name, rest = line.split(':', 1)
            val = re.search(r'[\d\.]+', rest)
            if val:
                names.append(name.strip().replace(' Junction', ''))
                values.append(float(val.group()))
    return names, np.array(values) # Using numpy array for easier math

# Parse the data
names_5th, vals_5th = parse_data(data_5th)
names_7th, vals_7th = parse_data(data_7th)

# Apply Min-Max Normalization: (value - min) / (max - min)
# This maps the data to a 0.0 to 1.0 scale
norm_5th = (vals_5th - np.min(vals_5th)) / (np.max(vals_5th) - np.min(vals_5th))
norm_7th = (vals_7th - np.min(vals_7th)) / (np.max(vals_7th) - np.min(vals_7th))

# Create the plot
fig, ax = plt.subplots(figsize=(16, 8))

# Plotting the normalized lines
ax.plot(names_5th, norm_5th, marker='o', linestyle='-', linewidth=2, label='5th Harmonic (Normalized)', color='#1f77b4')
ax.plot(names_7th, norm_7th, marker='s', linestyle='-', linewidth=2, label='7th Harmonic (Normalized)', color='#ff7f0e')

# Add labels, title, and formatting
ax.set_ylabel('Normalized Voltage Magnitude (0 to 1 Scale)', fontsize=12)
ax.set_title('Normalized Comparison of 5th and 7th Harmonic Voltages', fontsize=14)
ax.set_xticks(range(len(names_5th)))
ax.set_xticklabels(names_5th, rotation=45, ha='right', fontsize=10)
ax.legend(fontsize=12)
ax.grid(True, linestyle='--', alpha=0.7)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
